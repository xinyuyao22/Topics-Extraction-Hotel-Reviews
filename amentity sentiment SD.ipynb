# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Aspect-Based-Opinion-Mining-of-Hotel-Reviews" data-toc-modified-id="Aspect-Based-Opinion-Mining-of-Hotel-Reviews-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Aspect-Based Opinion Mining of Hotel Reviews</a></span><ul class="toc-item"><li><span><a href="#1.-Get-hotel-that-has-more-than-100-reviews" data-toc-modified-id="1.-Get-hotel-that-has-more-than-100-reviews-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>1. Get hotel that has more than 100 reviews</a></span></li><li><span><a href="#3.-Generate-aspect-rate-based-on-sentiment-analysis" data-toc-modified-id="3.-Generate-aspect-rate-based-on-sentiment-analysis-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>3. Generate aspect rate based on sentiment analysis</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Hotel Rank based on customer preference

# %% [markdown]
# ### 1. Using hotel in San Diego for example

# %%
import os
from os import listdir
import pandas as pd
from nltk.corpus import sentiwordnet as swn
df = pd.read_csv('C:/Users/xyyao/Documents/GitHub/Topics-Extraction-Hotel-Reviews - local/hotel-reviews/Datafiniti_Hotel_Reviews_Jun19.csv', header=0)
df.columns
# Out:
# Index(['id', 'dateAdded', 'dateUpdated', 'address', 'categories',
#        'primaryCategories', 'city', 'country', 'keys', 'latitude', 'longitude',
#        'name', 'postalCode', 'province', 'reviews.date', 'reviews.dateAdded',
#        'reviews.dateSeen', 'reviews.rating', 'reviews.sourceURLs',
#        'reviews.text', 'reviews.title', 'reviews.userCity',
#        'reviews.userProvince', 'reviews.username', 'sourceURLs', 'websites'],
#       dtype='object')

# %%
df.drop(columns=['dateAdded', 'dateUpdated', 'address', 'categories',
       'primaryCategories', 'keys', 'reviews.date', 'reviews.dateAdded',
       'reviews.dateSeen', 'reviews.userCity',
       'reviews.userProvince', 'reviews.username', 'sourceURLs', 'websites'], inplace = True)
df = df.rename(index=str, columns={'reviews.rating':'rating', 'reviews.sourceURLs': 'reviews_sourceURLs', 'reviews.text':'reviews_text', 'reviews.title': 'reviews_title'})

# %%
df1 = df[df.groupby(['id'])['id'].transform('count') > 50]

# %%
df_sd = df1[df1['city'] == 'San Diego']

# %%
import numpy as np
from collections import Counter
dic_sd = {}
for name in np.unique(df_sd['name']):
    dic_sd[name] = {'num_reviews':0, 'term_dict':Counter()}

# %% [markdown]
# ### 2. Generate term dict with sentiment score

# %%
import numpy as np
import pickle
from collections import Counter
import re

# nlp libraries/api
import en_core_web_lg
from spacy import displacy
import gensim
#from neuralcoref import Coref

spacy = en_core_web_lg.load()
#coref = Coref(nlp=spacy)

# %%
# Uncomment below if running for first time.
# Setup nltk corpora path and Google Word2Vec location
#google_vec_file = 'GoogleNews-vectors-negative300.bin'
#word2vec = gensim.models.KeyedVectors.load_word2vec_format(google_vec_file, binary=True)
#pickle.dump(word2vec, open("word2vec_google.pkl", 'wb'))

# If above script has been run, load saved word embedding
word2vec = pickle.load(open("word2vec_google.pkl", 'rb'))

# %%
def check_similarity(aspects, word):
    '''
    checks for word2vec similarity values between category word and the term
    returns most similar word
    '''
    similarity = []
    for aspect in aspects:
        sim = [word2vec.n_similarity([aspect], word.split())]
        for splited in word.split():
            sim.append(word2vec.n_similarity([aspect], [splited]))
        similarity.append(max(sim))
    # set threshold for max value
    if max(similarity) > 0.2:
        return aspects[np.argmax(similarity)]
    else:
        return None


def modify_sentiment(token, sentiment):
    for child in token.children:
        # if there's a adj modifier (i.e. very, pretty, etc.) add more weight to sentiment
        # This could be better updated for modifiers that either positively or negatively emphasize
        # can't catch "there are nowhere near enough loungers"
        if ((child.dep_ == "amod") or (child.dep_ == "advmod") or (child.dep_ == "neg")):
            try:
                senti = list(swn.senti_synsets(child, 'r'))[0]
                pos = senti.pos_score()
                neg = senti.neg_score()
                if child.dep_ == "neg":
                    sentiment *= -(neg + 1)
                else:
                    sentiment *= pos + 1
            except:
                continue
    return sentiment


def add_sentiment(token, sent_dict, sentiment):
    if (token.dep_ == "advmod"):
        return sent_dict
    elif (token.dep_ == "acomp"):
        sent_dict = for_acomp(token, sent_dict, sentiment)
    elif (token.dep_ == "amod"):
        sent_dict = for_amod(token, sent_dict, sentiment)
    elif (token.dep_ == "compound"):
        sent_dict = for_compound(token, sent_dict, sentiment)
    elif (token.dep_ == "conj"):
        sent_dict = add_sentiment(token.head, sent_dict, sentiment)
    elif (token.dep_ == "dobj"):
        sent_dict = for_dobj(token, sent_dict, sentiment)
    elif (token.dep_ == "relcl"):
        if token.head.pos_ == "NOUN" or token.head.pos_ == "PROPN":
            sent_dict[token.head.lemma_] += sentiment
    else:
        # if verb, check if there's a direct object
        if token.head.dep_ == "advcl" or token.head.dep_ == "ROOT":
            sent_dict = for_advcl(token.head, sent_dict, sentiment, token)
        for child in token.children:
            if (token.pos_ == "VERB") & (child.dep_ == "dobj") & (child.pos_ != 'PRON'):
                sent_dict = check_compound(child, sent_dict, sentiment, token)
            # check for nouns
            elif child.pos_ == "NOUN" or child.pos_ == "PROPN":
                sent_dict = check_compound(child, sent_dict, sentiment, token)
            if ((token.pos_ == "VERB") or (token.pos_ == "ADJ")) & (child.dep_ == "prep"):
                sent_dict = for_prep(child, sent_dict, sentiment)
    return sent_dict


def add_subchild(child, sent_dict, sentiment, token, added):
    if child.children == []:
        return sent_dict, added
    else:
        conj = 0
        for subchild in child.children:
            if (subchild.dep_ in ["compound", "amod", "nmod"]) & (subchild != token):
                sent_dict[subchild.lemma_ + ' ' + child.lemma_] += sentiment
                for sub in subchild.children:
                    if sub.pos_ in ["NOUN", "PROPN"]:
                        sent_dict[sub.lemma_ + ' ' + child.lemma_] += sentiment
                added = True
            # check for conjugates (a AND b), then add both to dictionary
            elif subchild.text == "and" or subchild.text == ",":
                conj += 1
        for subchild in child.children:
            if (conj > 0) & (subchild.pos_ == "NOUN" or subchild.pos_ == "PROPN"):
                sent_dict = check_compound(subchild, sent_dict, sentiment, child)
                conj -= 1
    return sent_dict, added


def check_compound(child, sent_dict, sentiment, token=None):
    added = False
    sent_dict, added = add_subchild(child, sent_dict, sentiment, token, added)
    if not added:
        sent_dict[child.lemma_] += sentiment
    return sent_dict


def for_compound(token, sent_dict, sentiment):
    if token.head.dep_ == "compound":
        sent_dict = for_compound(token.head, sent_dict, sentiment)
    elif token.head.pos_ in ["NOUN", "PROPN"]:
        sent_dict = check_compound(token.head, sent_dict, sentiment)
    return sent_dict


def for_acomp(token, sent_dict, sentiment):
    for ancestor in token.ancestors:
        if ancestor.dep_ == "attr":
            sent_dict[ancestor] += sentiment
        if ancestor.dep_ in ["advcl", "ROOT", "conj", "ccomp"]:
            sent_dict = for_advcl(ancestor, sent_dict, sentiment, token)
    return sent_dict


def for_advcl(ancestor, sent_dict, sentiment, token):
    for child in ancestor.children:
        if (child.dep_ in ["nsubj", "compound"]) & (child.pos_ in ["NOUN", "PROPN"]):
            sent_dict = check_compound(child, sent_dict, sentiment, token)
    return sent_dict


def for_amod(token, sent_dict, sentiment):
    if token.head.dep_ == "appos":
        sent_dict = check_compound(token.head, sent_dict, sentiment, token)
    elif token.head.dep_ == "pobj":
        if token.head.head.head.dep_ in ["advcl", "ROOT", "conj"]:
            sent_dict = for_advcl(token.head.head.head, sent_dict, sentiment, token)
    if token.head.pos_ == "NOUN" or token.head.pos_ == "PROPN":  # token.head.dep_ != "compound", so "free room delivery" not added twice
        sent_dict = check_compound(token.head, sent_dict, sentiment, token)
    return sent_dict


def for_dobj(token, sent_dict, sentiment):
    if token.head.dep_ == "conj":
        head = token.head.head
        head_child = token.head
    else:
        head = token.head
        head_child = token
    for child in head.children:
        if (child.dep_ == "nsubj") & (child.pos_ == "NOUN" or child.pos_ == "PROPN"):
            sent_dict = check_compound(child, sent_dict, sentiment, head_child)
    return sent_dict


def for_prep(token, sent_dict, sentiment):
    for child in token.children:
        if child.pos_ == "NOUN" or child.pos_ == "PROPN":
            sent_dict = check_compound(child, sent_dict, sentiment, token)
    return sent_dict


def feature_sentiment(sentence, sent_dict):
    '''
    input: dictionary and sentence
    function: appends dictionary with new features if the feature did not exist previously,
              then updates sentiment to each of the new or existing features
    output: updated dictionary
    '''
    sentence = spacy(sentence)
    for token in sentence:
        # check if the word is an opinion word, then assign sentiment
        try:
            senti = list(swn.senti_synsets(token.text, 'a'))[0]
            pos = senti.pos_score()
            neg = senti.neg_score()
            if (pos != 0) or (neg != 0):
                sentiment = pos if pos > neg else -neg
            else:
                continue
            # if target is an adverb modifier (i.e. pretty, highly, etc.)
            # but happens to be an opinion word, ignore and pass
            sentiment = modify_sentiment(token, sentiment)
            sent_dict = add_sentiment(token, sent_dict, sentiment)
        except:
            continue
    #print(sent_dict)
    return sent_dict


from nltk.tokenize import sent_tokenize


def split_sentence(text):
    '''
    splits review into a list of sentences using spacy's sentence parser
    '''
    review = spacy(text)
    bag_sentence = []
    start = 0
    for token in review:
        if token.sent_start:
            bag_sentence.append(review[start:(token.i - 1)])
            start = token.i
        if token.i == len(review) - 1:
            bag_sentence.append(review[start:(token.i + 1)])
    return bag_sentence


# Remove special characters using regex
def remove_special_char(sentence):
    return re.sub(r"[^a-zA-Z0-9.',:;?]+", ' ', sentence)


# "ROOMS", "CLEANLINESS", "VALUE", "SERVICE", "LOCATION", "CHECKIN", "BUSINESS", "FOOD", "BUILDING", "OTHER", "NOTRELATED"
def review_pipe(file, dict_sd):
    with open(file) as fp:
        Lines = fp.readlines()
        for line in Lines:
            name = line.split('|')[0]
            review = line.split('|')[1].split('Thank you for your')[0]

            # review = replace_pronouns(review)
            sentences = split_sentence(review)
            for sentence in sentences:
                sentence = remove_special_char(str(sentence))
                dict_sd[name]['term_dict'] = feature_sentiment(sentence.lower(), dict_sd[name]['term_dict'])
            dict_sd[name]['num_reviews'] += 1
    for name in dict_sd:
        for term in dict_sd[name]['term_dict']:
            dict_sd[name]['term_dict'][term] /= dict_sd[name]['num_reviews']/100
    return dict_sd

# %%
term_dict_sd = review_pipe('san_diego.txt', dic_sd)
term_dict_sd
# Out:
# {'Best Western Mission Bay': {'num_reviews': 69,
#   'term_dict': Counter({'western mission': 32.608695652173914,
#            'floor': 1.4492753623188408,
#            'room': 9.96376811594203,
#            'star hotel': 0.1811594202898551,
#            'breakfast': 18.297101449275363,
#            'people': 1.6304347826086958,
#            'sea': -2.536231884057971,
#            'town': 3.2608695652173916,
#            'parking': 4.166666666666667,
#            'hotel': 8.695652173913045,
#            'man': 1.2681159420289856,
#            'pool': 4.528985507246377,
#            'abd spa': 2.536231884057971,
#            'afternoon': 21.73913043478261,
#            'good afternoon': -0.1811594202898551,
#            'stay': 13.224637681159422,
#            'ordinary hotel': -1.0869565217391306,
#            'ugly hotel': -1.2681159420289856,
#            'musty hotel': -1.2681159420289856,
#            'standard': 0.1811594202898551,
#            'toilet': -0.3623188405797102,
#            'football team': -0.3623188405797102,
#            'youth team': -0.3623188405797102,
#            'parking chaos': -0.3623188405797102,
#            'noise': 0.7246376811594204,
#            'egg': -1.2681159420289856,
#            'behalf': -2.8985507246376816,
#            'expectation': 2.8985507246376816,
#            'satisfaction': 6.340579710144928,
#            'experience': 18.115942028985508,
#            'staff': 9.057971014492754,
#            'breakfast course': 0.9057971014492754,
#            'bed': -9.23913043478261,
#            'time': 37.137681159420296,
#            'breakfast lot': 1.4492753623188408,
#            'pool desk': 0.3623188405797102,
#            'front desk': 0.9057971014492754,
#            'decent room': 0.7246376811594204,
#            'feel': 0.7246376811594204,
#            'bare feel': -1.2681159420289856,
#            'parking lot': 1.2681159420289856,
#            'freeway access': 0.9057971014492754,
#            'freeway': -1.2681159420289856,
#            'child': -0.7246376811594204,
#            'early flight': 0.9057971014492754,
#            'good fare': -0.5434782608695653,
#            'western fare': 0.5434782608695653,
#            'standard fare': 1.0869565217391306,
#            'location': 7.971014492753624,
#            'minute': -0.3623188405797102,
#            'family': 1.4492753623188408,
#            'december': 0.1811594202898551,
#            'several day': 0.1811594202898551,
#            'day': 1.6304347826086958,
#            'exterior access': 0.5434782608695653,
#            'second night': 0.1811594202898551,
#            'window': -1.2681159420289856,
#            'inch': -0.1811594202898551,
#            'matter': 0.9057971014492754,
#            'young woman': 0.5434782608695653,
#            'mid': -0.5434782608695653,
#            'other room': 0.1811594202898551,
#            'safety': 0.3623188405797102,
#            'part': -0.5434782608695653,
#            'housekeeping': -0.5434782608695653,
#            'action guest': -0.5434782608695653,
#            'business': 6.884057971014493,
#            'guest': -5.434782608695652,
#            'pool area': -0.5434782608695653,
#            'access': 2.717391304347826,
#            'airport': 0.9057971014492754,
#            'drive': 0.0,
#            'balboa park': 1.0869565217391306,
#            'attraction': -1.8115942028985508,
#            'lot': 1.2681159420289856,
#            'trip experience': 1.4492753623188408,
#            'mission bay': 16.666666666666668,
#            'location kid': 0.3623188405797102,
#            'free breakfast': 1.6304347826086958,
#            'prime kid': 0.7246376811594204,
#            'kid': -0.3623188405797102,
#            'whale watching': 0.9057971014492754,
#            'whale': 0.9057971014492754,
#            'thought': -1.8115942028985508,
#            'hotel room': 0.5434782608695653,
#            'need': 0.9057971014492754,
#            'night': 2.536231884057971,
#            'noise pollution': -0.9057971014492754,
#            'price': 7.4275362318840585,
#            'frayed carpet': 0.1811594202898551,
#            'sag wallpaper': -0.1811594202898551,
#            'loud appliance': -0.9057971014492754,
#            'squeaky door': -0.3623188405797102,
#            'grittiness': -0.3623188405797102,
#            'carpet': -0.3623188405797102,
#            'wallpaper': -0.7246376811594204,
#            'appliance': 0.5434782608695653,
#            'evening': 2.173913043478261,
#            'recent stay': -0.3623188405797102,
#            'service': 2.8985507246376816,
#            'min drive': 0.9057971014492754,
#            'item': 0.3623188405797102,
#            'breakfast burrito': 1.0869565217391306,
#            'waffle': 0.1811594202898551,
#            'place': 4.891304347826087,
#            'morning': 9.96376811594203,
#            'sea world': -0.9057971014492754,
#            'park': -1.4492753623188408,
#            'beach': -0.3623188405797102,
#            'many attraction': -0.9057971014492754,
#            'more attraction': -0.9057971014492754,
#            'rug': -1.0869565217391306,
#            'bathtub footprint': -1.0869565217391306,
#            'wooden roller': 0.5434782608695653,
#            'future': -0.9057971014492754,
#            'stay staff': 0.3623188405797102,
#            'way': -0.1811594202898551,
#            'hotel experience': 1.0869565217391306,
#            'mistake': -0.1811594202898551,
#            'appearance': -0.1811594202898551,
#            'outside walkway': -0.5434782608695653,
#            'elevator': -1.6304347826086958,
#            'breakfast room': -1.2681159420289856,
#            'continental food': 0.1811594202898551,
#            'breakfast food': 0.1811594202898551,
#            'review': 1.992753623188406,
#            'property': -0.1811594202898551,
#            'area': 2.355072463768116,
#            'run': 0.7246376811594204,
#            'internet': 1.6304347826086958,
#            'san diego': 1.0869565217391306,
#            'choice': 1.0869565217391306,
#            'motel': 2.536231884057971,
#            'good': -0.3623188405797102,
#            'least': 0.7246376811594204,
#            'customer': 3.6231884057971016,
#            'team member': 3.2608695652173916,
#            'noise level': 2.355072463768116,
#            'value': 3.2608695652173916,
#            'survey': -1.0869565217391306,
#            'distance': 0.7246376811594204,
#            'towel': -1.8115942028985508,
#            'vagrant': -0.7246376811594204,
#            'continental breakfast': 1.0869565217391306,
#            'wifi': -1.0869565217391306,
#            'good towel': 0.7246376811594204,
#            'bedding towel': 2.8985507246376816,
#            'luxurious towel': 1.0869565217391306,
#            'ice machine': 0.5434782608695653,
#            'breakfast entree': 0.3623188405797102,
#            'continental entree': 0.3623188405797102,
#            'helpful staff': 1.992753623188406,
#            'courteous staff': 1.2681159420289856,
#            'pleasant staff': 1.4492753623188408,
#            'checkin checkout': 0.9057971014492754,
#            'hotel pool': -0.5434782608695653,
#            'highway food': 0.9057971014492754,
#            'fast food': 0.9057971014492754,
#            'highway': -0.1811594202898551,
#            'comment': 1.8115942028985508,
#            'western bay': 9.23913043478261,
#            'customer care': 4.528985507246377,
#            'comfortable bed': -0.9057971014492754,
#            'outdoor pool': -0.1811594202898551,
#            'other attraction': -0.5434782608695653,
#            'reservation': 0.5434782608695653,
#            'stuff': 1.0869565217391306,
#            'entire breakfast': -0.1811594202898551,
#            'good morning': 0.9057971014492754,
#            'compliment': 1.0869565217391306,
#            'queen bed': 0.1811594202898551,
#            'bathroom': -0.5434782608695653,
#            'dining': 0.5434782608695653,
#            'breakfast special': 0.9057971014492754,
#            sandwiches: 1.0869565217391306,
#            burritos: 1.0869565217391306,
#            'walk': 0.0,
#            'great location': -2.536231884057971,
#            'dog': 0.7246376811594204,
#            'clean room': -2.173913043478261,
#            'service board': -1.0869565217391306,
#            'tv board': -1.0869565217391306,
#            'room board': -1.0869565217391306,
#            'hair board': -1.0869565217391306,
#            'dryer board': -1.0869565217391306,
#            'iron board': -1.0869565217391306,
#            'full breakfast': 1.0869565217391306,
#            'affordable price': 1.2681159420289856,
#            'discount price': 1.4492753623188408,
#            'available price': 0.9057971014492754,
#            'comfortable price': 1.4492753623188408,
#            'citizensthe staff': 0.5434782608695653,
#            'rate': -0.9057971014492754,
#            'friendly staff': 1.0869565217391306,
#            'good staff': 0.7246376811594204,
#            'more store': -0.3623188405797102,
#            'vehicle': -0.5434782608695653,
#            'large vehicle': 0.5434782608695653,
#            'smoking urn': 0.1811594202898551,
#            'asthma': -1.992753623188406,
#            'guest smoking': -0.9057971014492754,
#            'room bathroom': 0.7246376811594204,
#            'bathroom size': -0.1811594202898551,
#            'hotel staff': 0.7246376811594204,
#            'good bay': 0.5434782608695653,
#            'bridge': 0.5434782608695653,
#            'red light': -1.8115942028985508,
#            'message': 0.5434782608695653,
#            'hour': 0.5434782608695653,
#            'note': 0.9057971014492754,
#            'thing': 2.173913043478261,
#            'amenity': 0.7246376811594204,
#            'convenient place': -1.0869565217391306,
#            'frill': -1.0869565217391306,
#            'resort': -0.7246376811594204,
#            'compromise': 1.0869565217391306,
#            'llimpos': -1.0869565217391306,
#            'good breakfast': -1.0869565217391306,
#            'option': -0.7246376811594204,
#            'level': -0.3623188405797102,
#            'wing': -0.1811594202898551,
#            'limited parking': 0.5434782608695653,
#            'work outlet': 0.1811594202898551,
#            'outlet': -0.9057971014492754,
#            'fire hazard': 0.9057971014492754,
#            'plug': 0.3623188405797102,
#            'half way': 0.3623188405797102,
#            'single employee': 1.2681159420289856,
#            'hotel employee': 1.2681159420289856,
#            'being': 1.2681159420289856,
#            'hot tub': 1.2681159420289856,
#            'many thing': -2.173913043478261,
#            'work order': 0.1811594202898551,
#            'machine': -0.5434782608695653,
#            'shower': 0.5434782608695653,
#            'variety': 2.717391304347826,
#            'first room': -0.9057971014492754,
#            'first floor': -0.7246376811594204,
#            'cockroach': -0.1811594202898551,
#            'issue': 0.7246376811594204,
#            'customer experience': 0.9057971014492754,
#            'problem': -0.9057971014492754,
#            'hot pool': 0.1811594202898551,
#            'tub pool': 0.1811594202898551,
#            'swimming pool': 0.1811594202898551,
#            'wi fi': 0.7246376811594204,
#            'money': 0.5434782608695653,
#            'box': -0.5434782608695653,
#            'available deposit': -0.5434782608695653,
#            'safe deposit': 0.5434782608695653,
#            'guest experience': 1.8115942028985508,
#            'work': 0.1811594202898551,
#            'deep cleaning': 0.1811594202898551,
#            'cleaning': 0.3623188405797102,
#            'smell': -1.6304347826086958,
#            'cologne': -0.3623188405797102,
#            'sheet': -2.173913043478261,
#            'breakfast area': -0.5434782608695653,
#            'conversation': 0.5434782608695653,
#            'music': -1.0869565217391306,
#            'attention': 0.9057971014492754,
#            'hotel manager': 0.3623188405797102,
#            'other guest': -1.2681159420289856,
#            'pillow': -1.0869565217391306,
#            'spacious buffet': 0.7246376811594204,
#            'incredible buffet': 0.7246376811594204,
#            'breakfast buffet': 0.7246376811594204,
#            'vacation': 1.0869565217391306,
#            'balboa': 0.5434782608695653,
#            'sock foot': -0.3623188405797102,
#            'clean foot': -1.0869565217391306,
#            'fan': 0.3623188405797102,
#            'western hotel': 1.0869565217391306,
#            'reason': -1.2681159420289856,
#            'majority': 1.0869565217391306,
#            'design': -1.2681159420289856,
#            'adjacent lot': 0.3623188405797102,
#            'view': 1.2681159420289856,
#            'clean place': -1.0869565217391306,
#            'p.m.': -0.9057971014492754,
#            'diego zoo': -0.5434782608695653,
#            'san zoo': -0.5434782608695653,
#            'quality': 0.9057971014492754,
#            'motel staff': 1.8115942028985508,
#            'non room': -1.0869565217391306,
#            'cone': -0.7246376811594204,
#            'information': -1.0869565217391306,
#            'general manager': -0.3623188405797102,
#            'parking space': -1.0869565217391306,
#            'your': -0.3623188405797102,
#            'assistance': -0.1811594202898551,
#            'development': -0.9057971014492754,
#            'easy access': -0.3623188405797102,
#            'quiet motel': 0.7246376811594204,
#            'clean motel': -0.9057971014492754,
#            'light headache': 0.1811594202898551,
#            'headache': -0.3623188405797102,
#            'good comment': -0.3623188405797102,
#            'ad': -0.3623188405797102,
#            'size room': -0.1811594202898551,
#            'king room': -0.1811594202898551,
#            'bed room': -0.1811594202898551,
#            'nice shower': 0.9057971014492754,
#            'powerful toilet': 2.173913043478261,
#            'easy shower': 1.2681159420289856,
#            'trip': 0.7246376811594204,
#            'dec': 0.1811594202898551,
#            'sleep': 1.0869565217391306,
#            'gentleman': 0.7246376811594204,
#            'deep appreciation': -0.9057971014492754,
#            'appreciation': 0.3623188405797102,
#            'memory': 1.0869565217391306,
#            'job': 1.4492753623188408,
#            'desk staff': 0.3623188405797102,
#            'key': 0.5434782608695653,
#            'w fruit': -0.9057971014492754,
#            'waffle maker': -0.9057971014492754,
#            'condiment': -0.9057971014492754,
#            'cereal': -0.9057971014492754,
#            'pasterie': -0.9057971014492754,
#            'yogurt': -1.8115942028985508,
#            'hot item': -0.7246376811594204,
#            'hot beverage': 0.5434782608695653,
#            'juice': 0.5434782608695653,
#            'i': -1.0869565217391306,
#            'surround area': -1.0869565217391306,
#            'building': 1.0869565217391306,
#            'fit': 0.9057971014492754,
#            'jesse': 1.2681159420289856,
#            'great variety': 1.0869565217391306,
#            'lady': 1.0869565217391306,
#            '. reception': -1.8115942028985508,
#            't.v reception': -1.8115942028985508,
#            '.': -1.8115942028985508,
#            'window latch': -0.1811594202898551,
#            'traffic noise': -0.3623188405797102,
#            'traffic': -0.3623188405797102,
#            'fabulous breakfast': 0.1811594202898551,
#            'fruit': -0.9057971014492754,
#            'comfortable place': 0.5434782608695653,
#            'breakfast gal': 0.7246376811594204,
#            'home': -1.0869565217391306,
#            'mildew mold': -0.1811594202898551,
#            'dust': -0.1811594202898551,
#            'good price': 1.0869565217391306,
#            'due room': 0.9057971014492754,
#            'fixture': -0.3623188405797102,
#            'western': 1.0869565217391306,
#            'coffee': 1.0869565217391306,
#            'setting': 0.5434782608695653,
#            'cpap machine': -0.3623188405797102,
#            'counter surface': -0.3623188405797102,
#            'large surface': -0.7246376811594204,
#            'bath area': 0.1811594202898551,
#            'sink area': 0.1811594202898551,
#            'tub': 0.5434782608695653,
#            'many tourist': -0.1811594202898551,
#            'clean hotel': 1.0869565217391306,
#            'basic hotel': 1.8115942028985508,
#            'good hotel': 0.7246376811594204,
#            'destination': 0.1811594202898551})},
#  'Best Western Plus Bayside Inn': {'num_reviews': 64,
#   'term_dict': Counter({'bayside inn': 34.375,
#            'distance': 7.03125,
#            'car': -0.5859375,
#            'room': 12.3046875,
#            'employee': 0.1953125,
#            'only issue': 0.78125,
#            'remote': 0.78125,
#            'fashioned remote': 0.5859375,
#            'hot tub': 1.7578125,
#            'pool': 5.2734375,
#            'world': 1.3671875,
#            'hotel': 13.0859375,
#            'juice': -0.1953125,
#            'donut': 0.78125,
#            'muffin': 0.78125,
#            'dinner': -0.9765625,
#            'western inn': 33.59375,
#            'many thing': 0.78125,
#            'easy thing': 0.78125,
#            'breakfast buffet': 7.2265625,
#            'little italy': -4.4921875,
#            'pool area': -0.78125,
#            'construction': 0.5859375,
#            'bed': -16.796875,
#            'breakfast': 14.6484375,
#            'touch': 5.078125,
#            'egg': -1.7578125,
#            'potato': 0.1953125,
#            'park italy': -0.5859375,
#            'waterfront italy': -0.5859375,
#            'expectation': 0.9765625,
#            'satisfaction': 1.3671875,
#            'experience': 3.7109375,
#            'next time': 3.90625,
#            'time': 12.890625,
#            'wonderful time': -0.390625,
#            'work': -1.171875,
#            'amicable way': 0.1953125,
#            'friendly way': 1.3671875,
#            'stay': 6.640625,
#            'dear n': 0.78125,
#            'jose n': 0.78125,
#            'roberto n': 0.78125,
#            'dear': 0.78125,
#            'walking': 0.9765625,
#            'staff': 22.65625,
#            'first trip': 0.78125,
#            'proximity': 2.1484375,
#            'city': 3.515625,
#            'cleanliness': 0.5859375,
#            'walk': 0.9765625,
#            'italy': -11.71875,
#            'reach': 0.9765625,
#            'desk staff': 4.8828125,
#            'question': 0.390625,
#            'advice': 0.390625,
#            'detail': 0.78125,
#            'water front': 0.9765625,
#            'place': 2.5390625,
#            'harbor': 1.7578125,
#            'guest': 0.0,
#            'comfortable bed': 1.5625,
#            'walk distance': -1.5625,
#            'helpful welcome': 0.5859375,
#            'fantastic welcome': 0.390625,
#            'facility': 2.34375,
#            'extra': 1.953125,
#            'transfer': 0.5859375,
#            'free transfer': 1.5625,
#            'amenity': 4.4921875,
#            'desk top': 0.9765625,
#            'table top': 0.9765625,
#            'table': 0.9765625,
#            'desk': 0.9765625,
#            'evening meal': 1.3671875,
#            'connect restaurant': 1.171875,
#            'price': 4.296875,
#            'always jar': -0.1953125,
#            'tip jar': -0.1953125,
#            'fun weekend': 0.1953125,
#            'several friend': 0.1953125,
#            'friend': -0.78125,
#            'italy section': -0.5859375,
#            'shuttle': 2.34375,
#            'driver': 1.5625,
#            'floor': -1.5625,
#            'view': 4.6875,
#            'spotless room': 0.9765625,
#            'great shower': 1.3671875,
#            'micrwave': 1.7578125,
#            'bonus': 1.7578125,
#            'lovely room': 0.78125,
#            'room furnishing': 0.78125,
#            'waiter': 0.9765625,
#            'more time': 0.1953125,
#            'location': 19.7265625,
#            'old gaslamp': -0.5859375,
#            'gaslamp': 0.0,
#            'base': 0.9765625,
#            'lovley stay': 0.78125,
#            'san diego': 1.7578125,
#            'denisemcc': 0.78125,
#            'feedback': 1.5625,
#            'care': 0.9765625,
#            'team': 0.5859375,
#            'regard': 10.15625,
#            'night': -1.5625,
#            'bw': 0.1953125,
#            'quiet room': -1.171875,
#            'comfortable room': -0.9765625,
#            'parking': 5.46875,
#            'elevator': 0.78125,
#            'non smoking': -0.390625,
#            'gentleman': 0.9765625,
#            'service': 5.6640625,
#            'way': 1.171875,
#            'shuttle service': 1.3671875,
#            'sea': -0.5859375,
#            'sleeper': -0.78125,
#            'diego zoo': 0.5859375,
#            'san zoo': 0.5859375,
#            'windfl0wer4576': 0.78125,
#            'ease': 0.78125,
#            'return stay': -0.1953125,
#            'comfy bed': -0.390625,
#            'pillow': -0.390625,
#            'function amenity': -2.9296875,
#            'water': -2.34375,
#            'cold': -0.390625,
#            'usable temperature': 0.390625,
#            'that': 0.78125,
#            'sauna': -0.390625,
#            'clerk': 0.78125,
#            'failure': 0.78125,
#            'same thing': 1.3671875,
#            'fairfield': 0.78125,
#            'quiet distance': 1.7578125,
#            'inclusive breakfast': -0.1953125,
#            'nice bed': -1.171875,
#            'itay': -0.5859375,
#            'farmer market': 0.5859375,
#            'little itay': 0.5859375,
#            'great garage': -0.9765625,
#            'tiny garage': -0.9765625,
#            'parking garage': 1.3671875,
#            'room water': -1.171875,
#            'wi fi': 1.171875,
#            'building': -0.1953125,
#            'arthurc0': 0.78125,
#            'apology': 2.5390625,
#            'maintenance team': 0.5859375,
#            'goal': 0.9765625,
#            'property': -0.1953125,
#            'energy strategy': 0.9765625,
#            'saving strategy': 0.9765625,
#            'convenient location': 0.78125,
#            'hotel staff': 1.953125,
#            'harbour': -0.390625,
#            'star banner': -0.390625,
#            'spangled banner': 0.1953125,
#            'day weekend': 0.78125,
#            'good inn': 0.78125,
#            'kind word': 0.78125,
#            'word': 0.0,
#            'sightseeing': 0.5859375,
#            'rate': 1.953125,
#            'thing': 1.953125,
#            'week': -0.390625,
#            'complementary breakfast': 0.390625,
#            'clean hotel': -0.1953125,
#            'affordable hotel': 0.5859375,
#            'good location': -0.1953125,
#            'local attraction': -0.78125,
#            'downtown': 1.7578125,
#            'overall complaint': 0.390625,
#            "di l'interruzione": -0.390625,
#            "quando l'interruzione": -0.390625,
#            "ci l'interruzione": -0.390625,
#            "sarebbe l'interruzione": -0.390625,
#            "stata l'interruzione": -0.390625,
#            'indoor pool': 1.3671875,
#            'pleasant staff': -1.171875,
#            'housekeeping staff': -0.1953125,
#            'lamp quarter': 0.1953125,
#            'gas quarter': 0.1953125,
#            'gas lamp': 0.1953125,
#            'decor': -1.5625,
#            'front staff': 2.5390625,
#            14: -0.390625,
#            'multi park': -0.390625,
#            'storey park': -0.390625,
#            'car park': -0.390625,
#            'downtown hotel': -0.9765625,
#            'short walk': 1.171875,
#            'bay': -0.1953125,
#            'small balcony': -0.1953125,
#            'balcony': -1.171875,
#            'bay breakfast': 1.3671875,
#            'complimentary breakfast': 0.5859375,
#            'plenty': 2.1484375,
#            'neighborhood': -0.78125,
#            'parking fee': 0.78125,
#            'parking lot': -0.78125,
#            'selection': 1.3671875,
#            'value': 2.5390625,
#            'lobby': -1.171875,
#            'tip': 0.390625,
#            'coronado': 0.390625,
#            'trip': 0.390625,
#            'biscuit': -0.9765625,
#            'cheese': -0.9765625,
#            'fruit': -1.5625,
#            'waterfront': -1.171875,
#            'day': -0.1953125,
#            'western bayside': 2.9296875,
#            hotel: 1.7578125,
#            'good bayside': 1.7578125,
#            'seaport village': -0.5859375,
#            'seaport': -0.5859375,
#            'dear kat4man4du': 0.78125,
#            'little balcony': 1.3671875,
#            'nice balcony': -0.5859375,
#            'italy festival': -0.5859375,
#            'art festival': -0.5859375,
#            'month': -0.78125,
#            'tv': 2.734375,
#            'complimentary buffet': -1.171875,
#            'early june': -0.78125,
#            'reason': -0.390625,
#            'humming': -0.78125,
#            'minute': -0.5859375,
#            'quality': 1.7578125,
#            'reception staff': 0.78125,
#            'business hotel': -0.390625,
#            'business': -0.390625,
#            'buffet breakfast': 1.3671875,
#            'first room': -0.390625,
#            'second room': -1.5625,
#            'well view': -0.78125,
#            'numerous place': 0.390625,
#            'full breakfast': 2.9296875,
#            'buffet': 0.78125,
#            'cost': 1.5625,
#            'tab555': 0.78125,
#            'standard': 2.34375,
#            'good standard': -0.5859375,
#            'problem': -0.5859375,
#            'fine': 0.5859375,
#            'great restaurant': -0.1953125,
#            'sarah': 0.78125,
#            'plan outage': 0.9765625,
#            'power outage': 0.9765625,
#            'job': 1.3671875,
#            'glowstick': 0.78125,
#            'flashlight': 0.78125,
#            'hot water': -0.78125,
#            'restaurant': -1.7578125,
#            'menu option': -1.171875,
#            'little lot': -0.5859375,
#            'italy lot': -1.171875,
#            'item': 0.5859375,
#            'company': 0.1953125,
#            'anthony p': 0.78125,
#            'bay area': -0.5859375,
#            'free breakfast': 2.734375,
#            'group': 0.390625,
#            'queen bed': -0.9765625,
#            'old mattress': 0.9765625,
#            'mattress': 0.5859375,
#            'one': 0.0,
#            towels: 1.3671875,
#            'constuction': -0.5859375,
#            'noise': -0.5859375,
#            'area': 1.3671875,
#            'little shop': 1.3671875,
#            'nice shop': -0.5859375,
#            'lack': -0.78125,
#            'trolley hop': 0.5859375,
#            'town hop': 0.5859375,
#            'tour': -1.171875,
#            'tourist': 0.390625,
#            'parking charge': 0.78125,
#            'start': 1.171875,
#            'hotel room': 1.5625,
#            'excellent room': 0.0,
#            'doc055': 0.78125,
#            'parking price': 1.7578125,
#            'review': -0.1953125,
#            'bayside room': 0.78125,
#            'other building': -0.390625,
#            'walking distance': 0.9765625,
#            'easy distance': 0.78125,
#            'star princess': 0.1953125,
#            'star': 0.1953125,
#            'cab ride': -0.390625,
#            'most hotel': -0.9765625,
#            hotel: -0.78125,
#            'tedreg': 0.78125,
#            'western': 1.171875,
#            'airport': 0.5859375,
#            'average breakfast': 0.5859375,
#            'drawback coffee': -0.9765625,
#            'morning coffee': -0.9765625,
#            'drawbuck': 0.1953125,
#            'safe people': 0.390625,
#            'friendly people': -0.5859375,
#            'bedding': -2.34375,
#            'choice': -1.171875,
#            'hot choice': 2.5390625,
#            'check': 0.9765625,
#            'convenient garage': 1.3671875,
#            'nice garage': 0.9765625,
#            'thermostat': -1.953125,
#            'diego whichnis': 0.5859375,
#            'san whichnis': 0.5859375,
#            'saving feature': 0.0,
#            'money feature': 0.0,
#            'other feature': 0.9765625,
#            'entrance': 0.78125,
#            'screen': 0.5859375,
#            'flat screen': -0.78125,
#            'coffee': -1.7578125,
#            'ironing board': -0.78125,
#            'ironing': -0.78125,
#            'iron': -0.78125,
#            'refrigerator': -1.953125,
#            'microwave': -0.78125,
#            'nice bathroom': -0.390625,
#            'fixture': 0.9765625,
#            'dry bathroom': 1.3671875,
#            'hair bathroom': 1.3671875,
#            'internet service': -0.5859375,
#            'internet': 0.5859375,
#            "o'clock check": 0.1953125,
#            'smoking room': 0.1953125,
#            'feature': 0.5859375,
#            'diego italy': -0.5859375,
#            'zonas italy': -0.5859375,
#            'san italy': -0.5859375,
#            'sun': -0.5859375,
#            'well hotel': 1.3671875,
#            'discomfort': 0.78125,
#            'grace manager': 1.171875,
#            'gerzensales manager': 1.171875,
#            'midway': 0.9765625,
#            'situation room': 3.125,
#            'room pool': 1.953125,
#            'situation pool': 1.953125,
#            'good pool': 0.78125,
#            'hot pool': 1.953125,
#            'good room': 1.953125,
#            'tub breakfast': 3.3203125,
#            'nice breakfast': 1.953125,
#            'spacious pool': 1.171875,
#            'rite aid': 0.390625,
#            'tram station': -0.5859375,
#            'outdoor pool': 0.1953125,
#            'heated pool': 0.1953125,
#            'town': 0.78125,
#            'bathroom': 1.5625,
#            'good internet': -1.171875,
#            'large tv': 0.0,
#            'chair': -1.171875,
#            'cable package': 1.171875,
#            'assorted bread': -0.5859375,
#            'cereal': -0.9765625,
#            'sausage': -0.5859375,
#            'bread': -0.390625,
#            'ingredient': -0.9765625,
#            'good service': -0.78125,
#            'actual service': 1.171875,
#            'deal': 1.7578125,
#            'equipment': 0.5859375,
#            'section': -0.9765625,
#            'good min': 0.78125,
#            'min': 1.171875,
#            'train station': 1.3671875,
#            'ride': 0.5859375,
#            'condo building': 0.5859375,
#            'breakfast choice': 0.1953125,
#            'nice choice': -1.171875,
#            'dollar deposit': 0.1953125,
#            'friendly driver': 1.5625,
#            'hassle': 0.78125,
#            'fitness center': 0.1953125,
#            'fitness': 0.1953125,
#            'continental breakfast': 0.1953125,
#            'family': -1.5625,
#            'meal': 1.171875,
#            'trouble': 0.1953125,
#            'pedestrian walkway': 0.1953125,
#            'short while': 0.390625,
#            'gal': 0.9765625,
#            'lot': 1.953125,
#            'computer': 0.5859375,
#            'use': 0.5859375,
#            'q tip': 0.78125,
#            'q': 0.78125,
#            'standard item': -0.9765625,
#            'other item': -0.5859375,
#            'room attendant': 0.390625,
#            'wifi': 0.5859375,
#            'wifi connection': 1.5625,
#            'food': 1.953125,
#            'portion': 0.390625,
#            'call': 0.1953125,
#            'checkout': 0.390625,
#            'spacious room': 0.78125,
#            'modest gym': 0.78125,
#            'adequate breakfast': 2.34375,
#            'gym': 1.5625,
#            'buffet item': -0.390625})},
#  'Best Western Plus Hacienda Hotel Old Town': {'num_reviews': 64,
#   'term_dict': Counter({'restaraunt': 0.5859375,
#            'town': 28.7109375,
#            'vista': 2.5390625,
#            'weekend': -1.5625,
#            'week day': -0.9765625,
#            'town factory': 4.1015625,
#            'tequila factory': 5.6640625,
#            'restaurant': 3.515625,
#            'holidays': 4.1015625,
#            'western': 2.34375,
#            'other western': 0.9765625,
#            'good western': -1.171875,
#            'friendly check': 0.5859375,
#            'check': 0.5859375,
#            'interruption': -0.390625,
#            'bw member': -0.1953125,
#            'gold member': -0.1953125,
#            'view': 5.859375,
#            'room furnishing': 2.734375,
#            'charming furnishing': 1.3671875,
#            'spanish architecture': 1.3671875,
#            'hacienda architecture': 1.3671875,
#            'property': 4.1015625,
#            'location': 14.6484375,
#            'battalion site': -0.1953125,
#            'mormon site': -0.1953125,
#            'tour': 1.3671875,
#            'lively restaurant': -0.1953125,
#            'mexican restaurant': 1.5625,
#            'numerous restaurant': 1.5625,
#            'feedback': 2.734375,
#            'service': 4.296875,
#            'important guest': -0.390625,
#            'guest': 2.1484375,
#            'responsive service': 1.5625,
#            'top floor': 0.1953125,
#            'hotel': 9.5703125,
#            'room': 7.421875,
#            'road': -0.1953125,
#            'back': -0.1953125,
#            'garage space': -0.390625,
#            'coffee maker': -0.5859375,
#            'coffee': -1.5625,
#            'plug': 0.390625,
#            'bathroom': 4.1015625,
#            'day': -0.390625,
#            'air con': 0.390625,
#            'layout': -0.5859375,
#            'difficulty': 0.78125,
#            'ground': 3.7109375,
#            'previous memory': -0.9765625,
#            'old town': 6.0546875,
#            'san diego': 0.9765625,
#            'rating': 1.3671875,
#            'one': 1.3671875,
#            'convenience': -0.1953125,
#            'hill': 1.3671875,
#            'entrance': 0.1953125,
#            'exercise': -0.5859375,
#            'part': 1.3671875,
#            lot: 1.171875,
#            'entire hotel': -0.1953125,
#            'different building': -2.5390625,
#            'building': 3.125,
#            'blding room': 0.78125,
#            'job': 1.171875,
#            'upper room': 0.5859375,
#            'lobby': 1.3671875,
#            'peanut heaven': 0.5859375,
#            'fare': -1.171875,
#            'wedding reception': 0.78125,
#            'great service': 0.390625,
#            'mother': 0.5859375,
#            'discussion': -0.1953125,
#            'second night': -0.1953125,
#            'same room': -0.1953125,
#            'other': -0.390625,
#            'lot': 1.3671875,
#            'evening': -0.390625,
#            'last evening': 0.9765625,
#            'several machine': 0.9765625,
#            'vending machine': 0.1953125,
#            'person': -0.9765625,
#            'morning': -0.390625,
#            'high standard': 0.1953125,
#            'usual standard': -0.390625,
#            'perspective': 0.78125,
#            'time': 9.5703125,
#            'modern hotel': 1.3671875,
#            'attractive hotel': -0.390625,
#            'spanish style': 0.5859375,
#            'maintain property': 1.171875,
#            'beautiful property': 1.171875,
#            'staff': 13.671875,
#            'internet signal': 0.78125,
#            'internet': -0.78125,
#            'bed': -6.0546875,
#            'breakfast buffet': 1.3671875,
#            'breakfast': 8.984375,
#            'walk distance': 3.515625,
#            'comfort': -1.171875,
#            'recommendation': 1.7578125,
#            'hotel town': 8.7890625,
#            'hacienda town': 10.546875,
#            'good town': 3.515625,
#            'western vieillissant': 1.171875,
#            'les raides': 0.1953125,
#            'escaliers raides': 0.1953125,
#            'sont raides': 0.1953125,
#            'les': 0.1953125,
#            'pas chance': 0.1953125,
#            'de chance': 0.1953125,
#            'hotel ground': 1.171875,
#            'pool': 2.9296875,
#            'amount': 1.953125,
#            'carpark': -0.1953125,
#            'block': -0.9765625,
#            'price': 0.78125,
#            'option': -0.390625,
#            'drink': 3.3203125,
#            'free drink': 1.3671875,
#            'experience': 3.7109375,
#            'book': -0.390625,
#            'reservation service': 1.171875,
#            'rate': 6.0546875,
#            'travel': -0.9765625,
#            'distance': 9.375,
#            'great staff': 0.390625,
#            'vanessa': 0.390625,
#            'nice room': 0.78125,
#            'hospitality goal': 0.390625,
#            'train': 0.78125,
#            'trolley': 0.78125,
#            'shop': 1.171875,
#            'team': 2.1484375,
#            'spring season': 1.171875,
#            'ambience': 0.9765625,
#            'maze': -0.390625,
#            'season': -0.390625,
#            'hot tub': 0.1953125,
#            pool: 0.9765625,
#            'first night': 0.0,
#            'long day': 0.0,
#            'that': -0.78125,
#            'p.m.': -0.78125,
#            'platter': -0.1953125,
#            'mexican food': 1.3671875,
#            'coupon': 0.78125,
#            'bill': 0.78125,
#            'knowledge': 0.78125,
#            'christmas': 0.5859375,
#            'christmas gift': 0.9765625,
#            'minute': 0.5859375,
#            'drag': 0.5859375,
#            'park': 1.5625,
#            'state': 0.390625,
#            'mexican fare': 1.171875,
#            'acapulco': 1.7578125,
#            'expectation': 0.78125,
#            'bobby': 1.5625,
#            'asset': 0.78125,
#            'sliding bathroom': -0.5859375,
#            'house keeping': 1.171875,
#            'breakfast lot': 0.78125,
#            'queue': -0.78125,
#            'people': 0.0,
#            'toast': 0.390625,
#            'gone': -0.5859375,
#            'note': -0.390625,
#            'top hospitality': 1.3671875,
#            'vacation experience': 1.171875,
#            'comfortable environment': 0.5859375,
#            'environment': -1.171875,
#            'unique shop': 0.5859375,
#            'train station': 1.171875,
#            'museum': 0.5859375,
#            'airport': 0.1953125,
#            'late arrival': 0.1953125,
#            'desk staff': 0.390625,
#            'service staff': 0.390625,
#            'facility': -0.390625,
#            'surprise': 1.3671875,
#            'overall experience': 1.953125,
#            'fact': 0.78125,
#            'plus': -0.1953125,
#            'shuttle driver': 2.5390625,
#            'room view': 0.9765625,
#            tub: 0.78125,
#            'complaint': 1.171875,
#            'murky water': -0.390625,
#            'coldish water': -0.390625,
#            'bath water': -0.390625,
#            'stay': 4.6875,
#            'great restaurant': 1.953125,
#            'lovely restaurant': -0.1953125,
#            'quick bed': -0.390625,
#            'hotel resort': 0.390625,
#            'street': 4.4921875,
#            'ocean': 0.5859375,
#            'hotel staff': 1.7578125,
#            'meal': 0.9765625,
#            'trolly': 0.9765625,
#            'floral landscaping': 0.9765625,
#            'tile stairway': 1.171875,
#            'tile': 2.34375,
#            'vibrant landscaping': 0.1953125,
#            'seating area': 1.171875,
#            'size room': 2.5390625,
#            'size': 5.078125,
#            'amenity': 2.9296875,
#            'uncomfortable couch': -0.5859375,
#            'small couch': -1.171875,
#            'cleaning': 1.171875,
#            'while': -0.9765625,
#            'compliment': 0.78125,
#            'review': 5.2734375,
#            'front lady': 1.5625,
#            'desk lady': 1.5625,
#            'western employee': 1.171875,
#            'different lady': 0.390625,
#            'room key': 0.1953125,
#            'key': 0.5859375,
#            'new employee': -0.390625,
#            'employee': 0.5859375,
#            'pet fee': 1.171875,
#            'husband': -0.5859375,
#            'drink voucher': 0.78125,
#            'puppy gizmo': 0.78125,
#            'parking fee': 0.5859375,
#            'credit card': -1.171875,
#            'lit candle': 0.390625,
#            'birthday': 2.734375,
#            'ankle foot': -0.5859375,
#            'place': -0.1953125,
#            'beach': 1.171875,
#            'restroom': 1.171875,
#            'firework': 0.390625,
#            'friendly personality': 0.5859375,
#            'personality': 0.390625,
#            'good employee': 0.78125,
#            'family employee': 1.953125,
#            'true employee': 1.171875,
#            'front clerk': 0.78125,
#            'desk clerk': 0.78125,
#            'word': 1.171875,
#            'way': 1.5625,
#            'western hacienda': 3.90625,
#            'bit': -1.171875,
#            'free dinner': 0.5859375,
#            'dinner': 1.7578125,
#            'value': 2.734375,
#            'area': 0.1953125,
#            'overall value': -0.9765625,
#            'call': -0.390625,
#            'bar lounge': 1.171875,
#            'food': 2.9296875,
#            'patio area': -0.78125,
#            'bloom bougainvillea': -0.390625,
#            'succulent': -0.390625,
#            'romantic feeling': 0.78125,
#            'complainer': -0.5859375,
#            'negative review': 0.390625,
#            'rare review': -1.3671875,
#            'western town': 1.7578125,
#            'site factory': 0.5859375,
#            'transit center': 0.5859375,
#            'town center': 0.5859375,
#            'qualcomm stadium': 0.390625,
#            'qualcomm': 0.390625,
#            'downtown': 0.390625,
#            'few western': 1.171875,
#            'matter': -1.171875,
#            'vacation': 0.9765625,
#            'football': -0.78125,
#            'problem': -0.9765625,
#            'total bill': -1.171875,
#            'customer service': -1.3671875,
#            'year': -0.390625,
#            'food beverage': 0.5859375,
#            'window': 0.5859375,
#            'air': -0.9765625,
#            'courtyard': 2.34375,
#            'courtyard area': -0.78125,
#            'quality': -0.78125,
#            'bonus': 1.3671875,
#            'suite': 0.5859375,
#            'pleasure': -0.78125,
#            'business': -0.78125,
#            'exterior': 1.953125,
#            'location town': 0.5859375,
#            'free breakfast': 0.78125,
#            'appetizer': 1.171875,
#            'parking situation': -0.78125,
#            'vintage charm': 0.78125,
#            'california charm': 0.78125,
#            'dean feather': 0.1953125,
#            'asst': 0.1953125,
#            'comment': 0.390625,
#            'ongoing effort': 0.390625,
#            'buffet breakfast': 0.5859375,
#            'carmen': -0.390625,
#            'greeting': 0.78125,
#            'city': 0.5859375,
#            'plant': 1.3671875,
#            'feb': -0.78125,
#            '600 one': 0.1953125,
#            'tequila restaurant': 1.171875,
#            'bus': -1.171875,
#            'local': 0.390625,
#            'description': 2.5390625,
#            'great tip': 0.390625,
#            'plan': -0.1953125,
#            'good hacienda': 1.5625,
#            'coffee machine': -0.9765625,
#            'gym': 0.390625,
#            'quality treadmill': 0.9765625,
#            'high quality': 0.9765625,
#            'weight': 0.5859375,
#            'bottled water': 0.5859375,
#            'towel': 0.5859375,
#            'level': 0.1953125,
#            'level room': 1.171875,
#            'humorous review': 1.5625,
#            'parking': -1.953125,
#            'close hotel': 1.171875,
#            'old coyote': 1.171875,
#            'cafe coyote': 1.7578125,
#            'town coyote': 1.7578125,
#            'town cafe': 1.7578125,
#            'town mexican': 0.5859375,
#            'servicewe': 0.5859375,
#            'western hotel': 2.34375,
#            'hacienda hotel': 1.953125,
#            'access': 0.9765625,
#            'computer': 0.78125,
#            'shuttle': 0.78125,
#            'point': 0.9765625,
#            'several building': 2.9296875,
#            'pool area': 0.390625,
#            'outdoor area': -0.78125,
#            'entire property': 0.9765625,
#            'saturday brunch': 1.5625,
#            'sunday brunch': 1.5625,
#            'special': 0.390625,
#            'town diego': -0.1953125,
#            'elevator': -1.3671875,
#            'room choice': -0.9765625,
#            'luggage': -0.78125,
#            'old room': -0.78125,
#            'new room': -0.78125,
#            'parking area': -0.5859375,
#            'parking space': -1.5625,
#            'local channel': -2.1484375,
#            'wine list': 1.171875,
#            'wine': 0.9765625,
#            'cigar': 0.9765625,
#            'street fair': 0.9765625,
#            'hit': 0.390625,
#            'summer': 0.78125,
#            'desk': 0.390625,
#            'hotel design': 1.3671875,
#            'sister': -0.390625,
#            'nice area': -0.390625,
#            'pool level': 0.5859375,
#            'plaza': 1.171875,
#            'fountain': 1.171875,
#            'planting': 1.171875,
#            'enclose area': -0.78125,
#            'dining area': -0.78125,
#            'terrace area': -0.78125,
#            'reviewer': 0.5859375,
#            'traveler': 0.5859375,
#            'photo': 0.5859375,
#            'addition': 1.3671875,
#            'fun area': -0.5859375,
#            'selfie area': -0.5859375,
#            'reason': 1.3671875,
#            'customer': 0.78125,
#            'fred': -0.390625,
#            'balcony': 1.3671875,
#            'quiet hotel': 1.3671875,
#            'nice hotel': -0.9765625,
#            'decor': 2.1484375,
#            'lack': 0.78125,
#            'night': 0.9765625,
#            'waiter': 1.171875,
#            'wound': 0.9765625,
#            'young lady': -1.3671875,
#            'question': -0.390625,
#            'volumn': -0.1953125,
#            'thing': -0.5859375,
#            'condition': 1.3671875,
#            'bad service': -0.1953125,
#            'wifi': -0.9765625,
#            'stair': 0.78125,
#            'knee': -0.9765625,
#            'con': 0.78125,
#            'inconvenience': 0.78125,
#            'hacienda': 0.5859375,
#            'transit plaza': -0.1953125,
#            'great pool': 0.1953125,
#            'flower': 1.171875,
#            'choice': 0.9765625,
#            'flower landscape': 0.1953125,
#            'landscape': 0.390625,
#            'excellent margarita': 1.171875,
#            'margarita': 1.5625,
#            'downtown hotel': -0.5859375,
#            'home': -0.390625,
#            'hotel room': 1.171875,
#            'impression': -0.9765625,
#            'star hotel': 0.1953125,
#            'array': 1.3671875,
#            'set': 0.5859375,
#            'bar': 1.3671875,
#            'sporting': 0.5859375,
#            'event': -0.390625,
#            'deal': 1.3671875,
#            'buffet': 0.5859375,
#            'happy thought': 0.390625,
#            'thought': 1.3671875,
#            'card bill': -0.1953125,
#            'credit bill': -0.1953125,
#            'pillow': 1.171875,
#            'smell': -0.5859375,
#            'poor sound': 0.5859375,
#            'heater': -0.5859375,
#            'sound': -1.3671875,
#            'noisy heater': 1.171875,
#            'proof': 1.171875,
#            'otsd restaurant': 1.171875,
#            'old area': 0.78125,
#            'town area': 1.3671875,
#            'smelly room': -1.171875,
#            'dirty room': -1.171875,
#            'far corner': 0.1953125,
#            'bay view': 0.9765625,
#            'side': 0.78125,
#            'arrogant staff': -1.3671875,
#            'rude staff': 0.390625,
#            'indifferent staff': -0.1953125,
#            'landscape property': 1.171875,
#            'main street': -0.1953125,
#            'more restaurant': -0.1953125,
#            'light property': 1.171875,
#            'sale': -0.1953125,
#            'comfortable place': 0.78125,
#            'clean place': -1.171875})},
#  'Best Western San Diego/Miramar Hotel': {'num_reviews': 65,
#   'term_dict': Counter({'western miramar': 35.38461538461539,
#            'room': 11.538461538461538,
#            'size bed': -0.1923076923076923,
#            'king bed': -0.1923076923076923,
#            'king size': -0.1923076923076923,
#            'sleeper': 0.7692307692307692,
#            'service': 5.1923076923076925,
#            'type': -0.1923076923076923,
#            'rate': 4.615384615384615,
#            'tourist area': 0.5769230769230769,
#            'tourist site': 1.346153846153846,
#            'tourist': 0.9615384615384615,
#            'moocoulter': 0.7692307692307692,
#            'western diego': 12.692307692307692,
#            'san diego': 13.076923076923077,
#            'quality service': 30.384615384615383,
#            'excellent service': 9.615384615384615,
#            'breakfast': 15.384615384615383,
#            'san miramar': 28.846153846153847,
#            'diego miramar': 28.846153846153847,
#            'lobby door': 0.5769230769230769,
#            'night window': -0.1923076923076923,
#            'proof window': -0.1923076923076923,
#            'bank': -0.3846153846153846,
#            'part': 1.346153846153846,
#            'corner': 0.7692307692307692,
#            'automatic door': -0.1923076923076923,
#            'granite counter': 1.346153846153846,
#            'granite': 0.5769230769230769,
#            'counter refrigerator': -1.5384615384615383,
#            'height refrigerator': -1.5384615384615383,
#            'counter': -1.5384615384615383,
#            'screeching sound': 0.5769230769230769,
#            'bathroom': -0.5769230769230769,
#            'outlet': -1.923076923076923,
#            'husband': -0.3846153846153846,
#            'side': -0.5769230769230769,
#            'pillow': -5.384615384615384,
# ...
#            'hosting': 1.0563380281690142,
#            'busy street': -0.17605633802816903,
#            'walk': 0.8802816901408451,
#            'part': -0.5281690140845071,
#            'gem': -1.5845070422535212,
#            'polish': -0.35211267605633806,
#            'comfortable hotel': -0.5281690140845071,
#            'sized room': 1.2323943661971832,
#            'complete room': 1.4084507042253522,
#            'nice room': 0.7042253521126761,
#            'excellent food': -0.35211267605633806,
#            'free coffee': 1.4084507042253522,
#            'excellent coffee': 0.5281690140845071,
#            'stay': 1.2323943661971832,
#            'attention': 1.2323943661971832,
#            'space': 0.17605633802816903,
#            'good rating': -0.17605633802816903,
#            'such rating': 1.0563380281690142,
#            'reason': 0.35211267605633806,
#            'volume': -0.35211267605633806,
#            'fact': 0.5281690140845071,
#            'vibe': 2.1126760563380285,
#            'road noise': 0.5281690140845071,
#            'size': 1.5845070422535212,
#            'care': 0.8802816901408451,
#            'property': -1.5845070422535212,
#            'drink': 3.8732394366197185,
#            'experience': 4.225352112676057,
#            'easy location': 0.8802816901408451,
#            'convenient location': 0.8802816901408451,
#            'bedding': -1.0563380281690142,
#            'professional service': -0.8802816901408451,
#            'linsday': 1.0563380281690142,
#            'paul': 1.0563380281690142,
#            'vahn': 1.0563380281690142,
#            'general manager': 0.8802816901408451,
#            'new manager': 0.35211267605633806,
#            'service attitude': 0.5281690140845071,
#            'customer attitude': 0.5281690140845071,
#            'business': 0.8802816901408451,
#            'daughter': 0.35211267605633806,
#            'cozy atmosphere': 0.35211267605633806,
#            'accommodation': 1.0563380281690142,
#            'atmosphere': -0.8802816901408451,
#            'wrist': -0.17605633802816903,
#            'attitude': 0.7042253521126761,
#            'other people': -1.0563380281690142,
#            'scooter': 0.7042253521126761,
#            'cool hotel': -0.17605633802816903,
#            'adult hotel': 0.17605633802816903,
#            'mile': -0.8802816901408451,
#            'airport': -1.0563380281690142,
#            'appetizer': 1.7605633802816902,
#            'beach ball': 0.5281690140845071,
#            'diego evening': 0.8802816901408451,
#            'san evening': 0.8802816901408451,
#            'surf film': 0.7042253521126761,
#            'surf': 0.7042253521126761,
#            'rerun': -0.5281690140845071,
#            'thing': 2.1126760563380285,
#            'crusier rental': 0.5281690140845071,
#            'beach rental': 0.5281690140845071,
#            'those': 0.8802816901408451,
#            'suggestion': 1.0563380281690142,
#            'bike': -0.7042253521126761,
#            'complimentary cocktail': 0.5281690140845071,
#            'patio area': -0.5281690140845071,
#            'patio': -0.5281690140845071,
#            'deal': 0.35211267605633806,
#            'bartender': 1.2323943661971832,
#            'occurance': 0.5281690140845071,
#            'small mosquito': -0.7042253521126761,
#            'several mosquito': -0.5281690140845071,
#            'problem': 0.0,
#            'complainer': 0.5281690140845071,
#            'quiet getaway': 1.2323943661971832,
#            'nice getaway': -0.8802816901408451,
#            'john': 1.2323943661971832,
#            'note': 0.5281690140845071,
#            'boyfriend': -0.5281690140845071,
#            'trip': -2.4647887323943665,
#            'diego hotel': 0.17605633802816903,
#            'san hotel': 0.17605633802816903,
#            'first night': 0.17605633802816903,
#            'burger dinner': 0.5281690140845071,
#            'burger': 4.049295774647888,
#            'brian': 1.7605633802816902,
#            'following evening': -0.35211267605633806,
#            'perfect proposal': -0.35211267605633806,
#            'proposal': 0.35211267605633806,
#            'sunset cliff': -0.35211267605633806,
#            'champagne': -0.8802816901408451,
#            'couple': 1.0563380281690142,
#            'weekend': 0.8802816901408451,
#            'thoughtfulness': 0.17605633802816903,
#            'great bar': 0.5281690140845071,
#            'surround bar': 0.8802816901408451,
#            'husband': 1.0563380281690142,
#            'love': -0.8802816901408451,
#            'guest experience': 5.985915492957747,
#            'possible experience': 1.0563380281690142,
#            'good experience': 0.7042253521126761,
#            'attraction': -0.8802816901408451,
#            'renovated motel': 0.35211267605633806,
#            'upscale motel': -0.35211267605633806,
#            'avalon': 2.1126760563380285,
#            'coffee': -0.8802816901408451,
#            'price': 1.9366197183098592,
#            'kind review': 1.7605633802816902,
#            'pricey hotel': 0.8802816901408451,
#            'neighborhood': -0.8802816901408451,
#            'street parking': -0.5281690140845071,
#            'great spot': -0.7042253521126761,
#            'distance': 0.7042253521126761,
#            'sleeper': -0.35211267605633806,
#            'sleep': -0.7042253521126761,
#            'early sleeper': -0.35211267605633806,
#            'fan': 0.35211267605633806,
#            'minute': -0.35211267605633806,
#            'available room': -0.5281690140845071,
#            'decision': 1.0563380281690142,
#            'great decor': -0.35211267605633806,
#            'retro decor': -0.35211267605633806,
#            'wifi': 0.5281690140845071,
#            'great neighborhood': -0.5281690140845071,
#            'residential neighborhood': -0.5281690140845071,
#            'main street': -1.0563380281690142,
#            'full dinner': 0.7042253521126761,
#            'course dinner': 0.7042253521126761,
#            'seasonal ingredient': 1.0563380281690142,
#            'star concierge': 0.17605633802816903,
#            'hotel concierge': 0.17605633802816903,
#            'urge': 0.8802816901408451,
#            'little gem': 0.8802816901408451,
#            'las vegas': 0.35211267605633806,
#            'corner': 0.35211267605633806,
#            'issue': -0.35211267605633806,
#            'good service': 0.17605633802816903,
#            'day stay': 0.5281690140845071,
#            'reception staff': 0.5281690140845071,
#            'difference': 0.35211267605633806,
#            'meal': 0.5281690140845071,
#            'outside terrace': -0.5281690140845071,
#            'garden terrace': -0.5281690140845071,
#            'november': -0.7042253521126761,
#            'garden heater': -0.7042253521126761,
#            'cosy area': 1.2323943661971832,
#            'nice area': 0.17605633802816903,
#            'array': 0.35211267605633806,
#            'seating area': 1.0563380281690142,
#            'one': -0.35211267605633806,
#            'standard': 1.0563380281690142,
#            'diego zoo': 0.5281690140845071,
#            'san zoo': 0.5281690140845071,
#            'seaworld': 0.5281690140845071,
#            'none': -0.7042253521126761,
#            'entire staff': 2.1126760563380285,
#            'private room': -0.8802816901408451,
#            'quiet room': -0.17605633802816903,
#            'environment': 2.1126760563380285,
#            'chef': 1.2323943661971832,
#            'wife': -2.2887323943661975,
#            'innkeeper': -0.35211267605633806,
#            'dealing': -0.7042253521126761,
#            'businessman': -0.5281690140845071,
#            'small businessman': 0.8802816901408451,
#            'small people': -0.8802816901408451,
#            'business people': -1.4084507042253522,
#            'hospitality': 4.929577464788733,
#            'goldfish': 0.5281690140845071,
#            'plate': -0.5281690140845071,
#            'concept': 1.5845070422535212,
#            'friendly pool': -0.7042253521126761,
#            'vacation pool': -0.7042253521126761,
#            'ace hotel': 0.8802816901408451,
#            'strand room': -0.35211267605633806,
#            'second': -0.7042253521126761,
#            'funky place': 1.2323943661971832,
#            'nice place': -1.0563380281690142,
#            'clean room': -1.0563380281690142,
#            'bar special': -0.35211267605633806,
#            'restaurant special': -0.35211267605633806,
#            'giant screen': 1.2323943661971832,
#            'several day': 0.17605633802816903,
#            'regard': 0.8802816901408451,
#            'retro hip': -0.35211267605633806,
#            'which': 0.7042253521126761,
#            'log': -0.35211267605633806,
#            'dinner': 1.4084507042253522,
#            'good burger': 1.0563380281690142,
#            'good beignet': 2.1126760563380285,
#            'soup': 1.0563380281690142,
#            'beignet': 1.0563380281690142,
#            'hospitality business': 0.5281690140845071,
#            'thank': -0.5281690140845071,
#            'pro detail': 0.7042253521126761,
#            'fun detail': 0.7042253521126761,
#            'pro': 1.7605633802816902,
#            'whole hotel': -0.5281690140845071,
#            'area': 1.2323943661971832,
#            'hotel guest': 0.0,
#            'con': 0.5281690140845071,
#            'side': -0.7042253521126761,
#            'flip side': 0.5281690140845071,
#            'air conditioner': -0.5281690140845071,
#            'feedback': 1.9366197183098592,
#            'pearl experience': 0.17605633802816903,
#            'staff member': 0.7042253521126761,
#            'caring staff': 0.35211267605633806,
#            'this': 0.7042253521126761,
#            'suite': -1.0563380281690142,
#            'cabrillo area': 1.0563380281690142,
#            'monument area': 1.0563380281690142,
#            'national area': 1.0563380281690142,
#            'downside': -0.5281690140845071,
#            'hard bed': -0.5281690140845071,
#            'traffic noise': 0.7042253521126761,
#            'pillow': -3.1690140845070425,
#            'figure': 0.35211267605633806,
#            'oxymoron': -0.35211267605633806,
#            'overall experience': 0.5281690140845071,
#            'boutique hotel': 1.5845070422535212,
#            'scale': 0.8802816901408451,
#            'food quality': 0.8802816901408451,
#            'wow quality': 0.8802816901408451,
#            'pet fish': 1.5845070422535212,
#            'loma': -0.17605633802816903,
#            'little place': 0.8802816901408451,
#            'perfect place': -0.5281690140845071,
#            'transportation': -0.17605633802816903,
#            'public transportation': 0.8802816901408451,
#            'century design': -0.8802816901408451,
#            'open design': -0.35211267605633806,
#            'mid century': -0.8802816901408451,
#            'modern design': -0.5281690140845071,
#            'plenty': -0.5281690140845071,
#            'number': -0.5281690140845071,
#            'staycation': -0.5281690140845071,
#            'c heat': 0.17605633802816903,
#            'tv': -1.0563380281690142,
#            'way': 1.5845070422535212,
#            'gouge': -0.17605633802816903,
#            'extra 10': 0.35211267605633806,
#            'happy holiday': 1.0563380281690142,
#            'holiday': 2.4647887323943665,
#            'dance music': -0.17605633802816903,
#            'destination spot': 0.5281690140845071,
#            'hip spot': 0.5281690140845071,
#            'quality modern': 0.8802816901408451,
#            'ikea modern': 0.8802816901408451,
#            'generic modern': 0.8802816901408451,
#            'ikea quality': -0.35211267605633806,
#            'courtyard': -1.0563380281690142,
#            'busser': 0.35211267605633806,
#            'james movie': 0.35211267605633806,
#            'bond movie': 0.35211267605633806,
#            'screen music': 0.35211267605633806,
#            'bond music': 0.35211267605633806,
#            'evening': 1.5845070422535212,
#            'unique experience': -0.17605633802816903,
#            'dining experience': 0.35211267605633806,
#            'next time': 0.7042253521126761,
#            'kyla': -0.5281690140845071,
#            'natalie': -0.5281690140845071,
#            'ashley': -0.5281690140845071,
#            'meghan': -0.5281690140845071,
#            'fianc': 0.5281690140845071,
#            'hotel restaurant': 0.7042253521126761,
#            'discount': 0.7042253521126761,
#            'pretty hip': 2.1126760563380285,
#            'beautiful hip': 1.2323943661971832,
#            'retro style': 0.35211267605633806,
#            'establishment': -0.17605633802816903,
#            'bed linen': 0.35211267605633806,
#            'situation': 0.0,
#            'person': 0.8802816901408451,
#            'fun vibe': -0.35211267605633806,
#            'cool experience': -0.17605633802816903,
#            'american motel': 0.17605633802816903,
#            'equippment': -0.35211267605633806,
#            'cool furniture': 0.7042253521126761,
#            'colour combination': 1.9366197183098592,
#            'modern vintage': 1.0563380281690142,
#            'detail': 1.4084507042253522,
#            'vintage': -0.35211267605633806,
#            'large room': 1.4084507042253522,
#            'simple room': 1.5845070422535212,
#            'activity': 1.7605633802816902,
#            'necessary point': -1.2323943661971832,
#            'red fish': -0.35211267605633806,
#            'negative point': 0.8802816901408451,
#            'many thing': 1.2323943661971832,
#            'wonderful thing': 0.17605633802816903,
#            'good bar': 0.7042253521126761,
#            'cool bar': 2.1126760563380285,
#            'groovy vibe': 1.0563380281690142,
#            'eclectic vibe': 2.4647887323943665,
#            'plasma tv': 0.7042253521126761,
#            'food bed': 0.8802816901408451,
#            'restaurant bed': 0.8802816901408451,
#            'free bed': 0.35211267605633806,
#            'wifi bed': 0.8802816901408451,
#            'comfy bed': 1.9366197183098592,
#            'excellent bed': -0.5281690140845071,
#            'small room': 1.7605633802816902,
#            'super room': -1.0563380281690142,
#            'jail cell': -0.35211267605633806,
#            'good': 1.0563380281690142,
#            'fun': 0.8802816901408451,
#            'option': -0.8802816901408451,
#            'mix': 0.5281690140845071,
#            'morning noise': 0.17605633802816903,
#            'facility parking': 0.5281690140845071,
#            'brussels sprout': -0.7042253521126761,
#            'movie screen': 0.17605633802816903,
#            'vertical garden': -1.0563380281690142,
#            'betta fish': 0.5281690140845071,
#            'bamboo': 0.5281690140845071,
#            'light': 0.5281690140845071,
#            'such atmosphere': 0.8802816901408451,
#            'delightful atmosphere': -0.35211267605633806,
#            'angela': 1.0563380281690142,
#            'dani': 0.7042253521126761,
#            'mike': 0.7042253521126761,
#            'dolly': 0.7042253521126761,
#            'night happening': -0.7042253521126761,
#            'game happening': -0.7042253521126761,
#            'restaurant hotel': 0.35211267605633806,
#            'bar hotel': 0.35211267605633806,
#            'much bed': 1.4084507042253522,
#            'bingo game': -0.7042253521126761,
#            'bingo': -0.7042253521126761,
#            game: 0.5281690140845071,
#            'relaxed ambiance': 0.8802816901408451,
#            'upbeat ambiance': -0.8802816901408451,
#            'fish taco': 1.0563380281690142,
#            'unique service': 1.5845070422535212,
#            'clean service': 1.4084507042253522,
#            'great service': 2.1126760563380285,
#            'personable name': 0.8802816901408451,
#            'different name': 0.8802816901408451,
#            'card': -0.5281690140845071,
#            'beach': 0.35211267605633806,
#            'town': 0.5281690140845071,
#            'mod vibe': 0.5281690140845071,
#            'retro vibe': 0.5281690140845071,
#            'hip vibe': 0.5281690140845071,
#            'full vibe': 0.5281690140845071,
#            'mod': 0.5281690140845071,
#            'hint': -0.5281690140845071,
#            'goldfish friend': -0.5281690140845071,
#            'only mishap': 1.2323943661971832,
#            'special hour': 1.2323943661971832})}}

# %%
from collections import defaultdict
def rank_hotel(term):
    rank_hotel = defaultdict(int)
    for name in term_dict_sd:
        for t in term_dict_sd[name]['term_dict']:
            try:
                sim = word2vec.n_similarity(t.split(), [term])
                if sim > 0.3:
                    print(t)
                    rank_hotel[name] += term_dict_sd[name]['term_dict'][t]
            except:
                continue
    return rank_hotel

# %%
rank_hotel = rank_hotel('breakfast')
# Out:
# breakfast
# hotel
# ordinary hotel
# breakfast course
# bed
# breakfast lot
# good fare
# day
# free breakfast
# hotel room
# night
# evening
# breakfast burrito
# waffle
# morning
# breakfast room
# continental food
# breakfast food
# continental breakfast
# breakfast entree
# continental entree
# fast food
# comfortable bed
# entire breakfast
# good morning
# queen bed
# dining
# breakfast special
# full breakfast
# guest smoking
# room bathroom
# hotel staff
# good breakfast
# hotel employee
# shower
# breakfast area
# spacious buffet
# incredible buffet
# breakfast buffet
# bed room
# nice shower
# easy shower
# sleep
# cereal
# yogurt
# hot beverage
# fabulous breakfast
# breakfast gal
# coffee
# clean hotel
# basic hotel
# good hotel
# bayside inn
# hotel
# donut
# muffin
# dinner
# breakfast buffet
# bed
# breakfast
# comfortable bed
# evening meal
# connect restaurant
# great shower
# lovely room
# night
# comfy bed
# inclusive breakfast
# nice bed
# hotel staff
# good inn
# complementary breakfast
# clean hotel
# affordable hotel
# downtown hotel
# bay breakfast
# complimentary breakfast
# biscuit
# cheese
# day
# complimentary buffet
# reception staff
# business hotel
# buffet breakfast
# full breakfast
# buffet
# great restaurant
# restaurant
# menu option
# free breakfast
# queen bed
# hotel room
# bayside room
# average breakfast
# drawback coffee
# morning coffee
# coffee
# o'clock check
# smoking room
# well hotel
# good room
# tub breakfast
# nice breakfast
# assorted bread
# cereal
# sausage
# bread
# breakfast choice
# continental breakfast
# meal
# food
# adequate breakfast
# buffet item
# restaraunt
# restaurant
# lively restaurant
# mexican restaurant
# numerous restaurant
# hotel
# coffee
# day
# wedding reception
# evening
# last evening
# morning
# bed
# breakfast buffet
# breakfast
# hotel town
# hotel ground
# drink
# free drink
# nice room
# platter
# breakfast lot
# toast
# great restaurant
# lovely restaurant
# quick bed
# hotel staff
# meal
# drink voucher
# free dinner
# dinner
# bar lounge
# food
# food beverage
# free breakfast
# appetizer
# buffet breakfast
# tequila restaurant
# coffee machine
# town cafe
# hacienda hotel
# saturday brunch
# sunday brunch
# dining area
# quiet hotel
# nice hotel
# night
# excellent margarita
# margarita
# downtown hotel
# hotel room
# buffet
# more restaurant
# size bed
# king bed
# breakfast
# bed
# waffle
# bread
# breakfast staff
# comfy bed
# nice bed
# hotel
# night
# guest service
# holiday inn
# nice room
# continental breakfast
# hot breakfast
# reception
# bed breakfast
# comfortable breakfast
# breakfast room
# nice motel
# day
# egg dish
# job breakfast
# nice breakfast
# hot buffet
# cereal paring
# sausage
# omelet
# property breakfast
# hotel staff
# smoking room
# choice hotel
# new hotel
# breakfast option
# waffle option
# cereal
# pastry
# other hotel
# good hotel
# look hotel
# diego hotel
# breakfast area
# morning
# hot food
# night sleep
# restaurant
# several restaurant
# fast food
# several eatery
# eatery
# meal
# deluxe bar
# breakfast bar
# complimentary bar
# breakfast item
# good fare
# hotel
# hotel staff
# perfect hotel
# awesome hotel
# restaurant
# bed
# size bed
# queen bed
# coffee
# cafe
# king bed
# breakfast
# breakfast buffet
# bed room
# complimentary parking
# night
# coffee lot
# onsite restaurant
# hotel help
# excellent restaurant
# close restaurant
# other restaurant
# hotel ground
# diner
# sleep
# food
# low bed
# quality bed
# comfy bed
# clean bed
# shower
# clean hotel
# hard bed
# nice room
# dinner food
# caf
# room service
# meal
# breakfast package
# morning shuttle
# morning
# good food
# dinner
# pool bed
# food place
# drink
# large bbq
# bbq
# on restaurant
# site restaurant
# type restaurant
# diner restaurant
# helpful hotel
# guest microwave
# restaurant staff
# fun bar
# chicken soup
# noodle soup
# breakfast food
# breakfast
# cost hotel
# simple hotel
# hotel
# morning
# cook cookie
# coffee
# cheap restaurant
# several restaurant
# night
# cookie
# food
# nice room
# breakfast area
# workplace canteen
# bed
# complimentary breakfast
# good breakfast
# good hotel
# breakfast sausage
# free breakfast
# hotel fee
# hotel choice
# hotel shuttle
# hotel fare
# pancake machine
# hotel parking
# day
# excellent restaurant
# hotel staff
# continental breakfast
# smoking room
# pancake
# coffee machine
# restaurant
# staff breakfast
# friendly breakfast
# fantastic breakfast
# king bed
# hot day
# shower
# sweet muffin
# mini omelette
# good restaurant
# good morning
# evening
# buffet
# yogurt
# cereal
# muffin
# bagel
# toast
# coffee tea
# pleasant afternoon
# gravy
# biscuit
# sausage
# great hotel
# yogurt parfait
# breakfast room
# waffle
# bayside inn
# hotel service
# menu time
# dining area
# great food
# breakfast
# eat area
# size bed
# queen bed
# bed
# complimentary breakfast
# breakfast place
# hotel
# workout room
# restaurant
# cookie
# nice hotel
# breakfast area
# donut
# hot cereal
# pancake
# sausage
# bacon
# pastry
# cereal
# hotel stay
# breakfast room
# excellent breakfast
# dinner
# average breakfast
# least breakfast
# waffle
# reception area
# other hotel
# free breakfast
# morning
# nice room
# tea
# coffee
# free coffee
# day
# lounge area
# include breakfast
# fruit muffin
# bread muffin
# bread
# yogurt
# oatmeal
# king bed
# clean hotel
# quiet hotel
# wonderful breakfast
# hot waffle
# complimentary coffee
# hotel staff
# hot chocolate
# comfortable bed
# night
# sleep
# evening
# free snack
# drink
# snack
# morning breakfast
# hotel choice
# taco bell
# taco
# meeting
# fitness room
# appetizer
# standard breakfast
# breakfast breakfast
# hampton breakfast
# restuarant
# nice hotel
# breakfast
# shower
# coffee machine
# many restaurant
# local restaurant
# nice room
# bed
# cereal
# pastry
# hotel room
# comfortable bed
# king bed
# continental breakfast
# breakfast area
# hotel
# wedding day
# complimentary continental
# hearty continental
# meal
# night
# include breakfast
# kitchenette
# hotel breakfast
# sandbox pizza
# morning
# complimentary breakfast
# restaurant pub
# price hotel
# beach hotel
# front hotel
# right hotel
# early evening
# package pastry
# toast
# bagel
# coffee
# other breakfast
# nice breakfast
# free breakfast
# waffle making
# waffle
# drink
# dining
# gluten muffin
# yogurt
# inn
# menu
# restaurant
# amazing restaurant
# day
# other hotel
# sized bed
# fresh bagel
# lounge chair
# lounge
# typical hotel
# food place
# deli
# luxury hotel
# room decor
# breakfast item
# beach restaurant
# shopping restaurant
# breakfast
# bed
# hotel
# shower
# night
# free breakfast
# choice hotel
# hot breakfast
# restaurant
# meal
# pastry
# yogurt
# patty
# cereal
# sausage
# sleeping area
# hotel amenity
# hotel staff
# house breakfast
# waffle breakfast
# restaurant breakfast
# decent breakfast
# bunk bed
# sleep
# morning
# breakfast room
# sitting room
# food
# coffee
# day
# trendy hotel
# comfortable lodging
# complimentary breakfast
# reception staff
# great bed
# separate lounge
# lounge
# daily breakfast
# king bed
# breakfast area
# bed room
# bunk room
# hotel member
# morning breakfast
# mission hotel
# include breakfast
# granola bar
# free buffet
# breakfast buffet
# best buffet
# dining area
# other hotel
# nice motel
# restaraunt
# complementary buffet
# next morning
# deluxe breakfast
# fi breakfast
# wi breakfast
# bed
# day
# first hotel
# food
# cocktail
# strong coffee
# nice coffee
# comfortable bed
# restaurant area
# restaurant pool
# hotel
# restaurant
# lodging place
# lodging
# hotel staff
# night
# small hotel
# reception
# comfortable hotel
# nice room
# free coffee
# excellent coffee
# drink
# cool hotel
# adult hotel
# appetizer
# diego evening
# complimentary cocktail
# diego hotel
# burger dinner
# burger
# coffee
# pricey hotel
# sleep
# full dinner
# course dinner
# hotel concierge
# reception staff
# meal
# private room
# chef
# bar special
# restaurant special
# dinner
# good burger
# good beignet
# soup
# beignet
# whole hotel
# hotel guest
# hard bed
# busser
# evening
# dining experience
# hotel restaurant
# bed linen
# food bed
# restaurant bed
# free bed
# wifi bed
# comfy bed
# excellent bed
# restaurant hotel
# bar hotel
# much bed
# fish taco
# special hour

# %%
sorted(rank_hotel.items(), key=lambda v: v[1], reverse=True)
# Out:
# [('Best Western Plus Bayside Inn', 72.4609375),
#  ('The Pearl Hotel', 67.07746478873241),
#  ('Best Western Plus Hacienda Hotel Old Town', 62.109375),
#  ('Best Western San Diego/Miramar Hotel', 60.00000000000001),
#  ('Quality Suites San Diego SeaWorld Area', 59.72222222222224),
#  ('Best Western Yacht Harbor Hotel', 59.65909090909087),
#  ('Best Western Mission Bay', 51.99275362318842),
#  ('Hampton Inn San Diego Del Mar', 45.875),
#  ('Best Western Seven Seas', 31.81818181818182),
#  ('Ocean Park Inn', 22.222222222222232)]
